# %%
# Instead of downloading a csv file and updating analysis and visualisation of the stock price,
# the NVDA stock price history can be extracted directly using Pandas Datareader and the
# Yahoo Finance API
# Data extraction from the World Bank can also be facilitated using an API

import pandas_datareader as pdr

# %%
# !pip install pandas_datareader

# %%
import pandas_datareader as pdr

# %%
import datetime as dt

# %%
ticker = "NVDA"
start = dt.datetime(2019, 1, 1)

data = pdr.get_data_yahoo(ticker, start)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_944\533048733.py in <module>
#       2 start = dt.datetime(2019,1,1)
#       3
# ----> 4 data = pdr.get_data_yahoo(ticker, start)
#
# ~\anaconda3\lib\site-packages\pandas_datareader\data.py in get_data_yahoo(*args, **kwargs)
#      78
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#      81
#      82
#
# ~\anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# ...

# %%
# !pip install yfinance

# %%
import pandas_datareader.data as pdr
import yfinance as yfin
yfin.pdr_override()

# To get around a breaking change in the yahoo finance API

# %%
ticker = "NVDA"
start = dt.datetime(2019, 1, 1)

data = pdr.get_data_yahoo(ticker, start)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2019-01-02  32.660000  34.619999  32.512501  34.055000  33.799732  50875200
# 2019-01-03  33.447498  33.790001  31.922501  31.997499  31.757648  70555200
# 2019-01-04  32.735001  34.432499  32.424999  34.047501  33.792278  58562000
# 2019-01-07  34.625000  36.222500  34.107498  35.849998  35.581276  70916000
# 2019-01-08  36.672501  36.695000  34.224998  34.957500  34.695465  78601600

# %%
# Checking the Date column is indexed as datetime, which it is.
data.index
# Out:
# DatetimeIndex(['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#                '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11',
#                '2019-01-14', '2019-01-15',
#                ...
#                '2023-03-27', '2023-03-28', '2023-03-29', '2023-03-30',
#                '2023-03-31', '2023-04-03', '2023-04-04', '2023-04-05',
#                '2023-04-06', '2023-04-10'],
#               dtype='datetime64[ns]', name='Date', length=1075, freq=None)

# %%
data.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-04-03  275.089996  280.000000  273.359985  279.649994  279.649994
# 2023-04-04  279.660004  280.000000  273.070007  274.529999  274.529999
# 2023-04-05  268.290009  269.980011  263.950012  268.809998  268.809998
# 2023-04-06  265.839996  270.799988  264.269989  270.369995  270.369995
# 2023-04-10  268.230011  276.209991  266.690002  275.790009  275.790009
#
#               Volume
# Date
# 2023-04-03  39871600
# 2023-04-04  36859200
# 2023-04-05  51501500
# 2023-04-06  39765400
# 2023-04-10  39438000

# %%
ticker = "NVDA"
start = dt.datetime(2020, 1, 1)
end = dt.datetime(2023, 4, 10)

data = pdr.get_data_yahoo(ticker, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  59.687500  59.977501  59.180000  59.977501  59.760399  23753600
# 2020-01-03  58.775002  59.457500  58.525002  59.017502  58.803875  20538400
# 2020-01-06  58.080002  59.317501  57.817501  59.264999  59.050491  26263600
# 2020-01-07  59.549999  60.442501  59.097500  59.982498  59.765381  31485600
# 2020-01-08  59.939999  60.509998  59.537498  60.095001  59.877476  27710800

# %%
# Pulling data from Nasdaq
nasdaq_sym = pdr.get_nasdaq_symbols()

# %%
nasdaq_sym
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Investment Managers Series Trust II AXS First ...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
# ...               ...                                                ...
# ZXYZ.A           True                 Nasdaq Symbology Test Common Stock
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZYME             True                      Zymeworks Inc. - Common Stock
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# ...

# %%
nasdaq_sym.loc['NVDA']
# Out:
# Nasdaq Traded                                    True
# Security Name       NVIDIA Corporation - Common Stock
# Listing Exchange                                    Q
# Market Category                                     Q
# ETF                                             False
# Round Lot Size                                  100.0
# Test Issue                                      False
# Financial Status                                    N
# CQS Symbol                                        NaN
# NASDAQ Symbol                                    NVDA
# NextShares                                      False
# Name: NVDA, dtype: object

# %%
# How many symbols make up the NASDAQ index?
len(nasdaq_sym)
# Out:
# 11557

# %%
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html
# Next, in phase 6, the volatility of the NVDA will be calculated
